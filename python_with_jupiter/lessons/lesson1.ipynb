# %% [markdown]
# # 1. numpy tutorial

# %%
import numpy as np

# %%
a = np.array([1,2,3]) 
print(a)
# Out:
# [1 2 3]

# %%
b = np.array([[9,0,0,8],[5,4,5,6]]) 
print(b)
# Out:
# [[9 0 0 8]
#  [5 4 5 6]]

# %%
#get dimension
a.ndim ##1
b.ndim ##2
# Out:
# 2

# %%
#get shape
b.shape
# Out:
# (2, 4)

# %%
#get type
a.dtype
# Out:
# dtype('int64')
